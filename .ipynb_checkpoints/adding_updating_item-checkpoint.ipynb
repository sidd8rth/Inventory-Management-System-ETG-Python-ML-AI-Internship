# %% [markdown]
# # This file contains four functions.
# #### 1) dump_data -- It dumps json data from file and save it in a json file
# #### 2) load_data --  It load json data from file and loads it in a record variable
# #### 3)  add_new_item_to_inventory -- to add new item to the inventory
# #### 4) updating_an_item -- update item

# %%
import json

# %%
def load_data():
    with open("records.json", "r") as fd:
        r = fd.read()
    
    record = json.loads(r)
    return record

# %%
def dump_data(record):
    record_js = json.dumps(record)
    
    with open("records.json", "w") as fd:
        fd.write(record_js)

# %% [markdown]
# # Run the above code first

# %%
def add_new_item_to_inventory():
    record = load_data()
    #print(record)
    prod_id = int(input("Enter product id : "))
    title = input("Enter product name : ")
    type = input("Enter product type : ")
    description = input("Enter product description : ")
    height = int(input("Enter product height : "))
    width = int(input("Enter product width : "))
    price = float(input("Enter cost of product : "))
    rating = int(input("Enter rating of product"))
    quantity = int(input("Enter no. of quantity in stock"))
    
    record[prod_id] = {"title" : title, "type" : type, "description" : description,
                      "height" : height, "width" : width, "price" : price,
                      "rating" : rating, "quantity" : quantity}
    
    dump_data(record)
        
# add_new_item_to_inventory()

# %%
def updating_an_item():
    record = load_data()
    prod_id = input("Enter product id of product you want to update : ")
    feature_to_update = input("Enter name of feature to update : ")
    new_val = input("Enter new value of feature : ")
    if isinstance(record[prod_id][feature_to_update], str):
        record[prod_id][feature_to_update] = new_val
    elif isinstance(record[prod_id][feature_to_update], int):
        record[prod_id][feature_to_update] = int(new_val)
    elif isinstance(record[prod_id][feature_to_update], float):
        record[prod_id][feature_to_update] = float(new_val)
    
    dump_data(record)
    
updating_an_item()
# Out:
# Enter product id of product you want to update : 11251
# Enter name of feature to update : quantity
# Enter new value of feature : 102

# %%
i =  int(input())
while True:
    print("Enter 1 for adding item to inventory , 2 to update the inventory and 0 if you want to exit.")
    if i == 1:
        add_new_item_to_inventory()
    elif i == 2:
        updating_an_item()
    elif i == 0:
        exit()
    i = int(input())

# %%
with open("records.json", "r") as fd:
    r = fd.read()
    
record = json.loads(r)
for j,i in enumerate(record):
    print("========" + str(j) + "========")
    print("Name = " + str(record[i]["title"]))
    print("Type = " + str(record[i]["type"]))
    print("Description = " + str(record[i]["description"]))
    print("Height = " + str(record[i]["height"]))
    print("Weight = " + str(record[i]["width"]))
    print("Price = " + str(record[i]["price"]))
    print("Rating = " + str(record[i]["rating"]))
    print("Quantity = " + str(record[i]["quantity"]))
    print("================================")
print(record)
# Out:
# Name = Brown eggs
# Type = dairy
# Description = Raw organic brown eggs in a basket
# Height = 600
# Weight = 400
# Price = 28.1
# Rating = 4
# Quantity = 107
# Name = Sweet fresh stawberry
# Type = fruit
# Description = Sweet fresh stawberry on the wooden table
# Height = 450
# Weight = 299
# Price = 29.45
# Rating = 4
# Quantity = 54
# Name = Asparagus
# Type = vegetable
# Description = Asparagus with ham on the wooden table
# Height = 450
# Weight = 299
# Price = 18.95
# Rating = 3
# Quantity = 101
# Name = Green smoothie
# Type = dairy
# Description = Glass of green smoothie with quail egg's yolk, served with cocktail tube, green apple and baby spinach leaves over tin surface.
# Height = 600
# Weight = 399
# Price = 17.68
# Rating = 4
# Quantity = 95
# Name = Raw legums
# Type = vegetable
# Description = Raw legums on the wooden table
# Height = 450
# Weight = 299
# Price = 17.11
# Rating = 2
# Quantity = 145
# Name = Baking cake
# Type = dairy
# Description = Baking cake in rural kitchen - dough  recipe ingredients (eggs, flour, sugar) on vintage wooden table from above.
# Height = 450
# Weight = 675
# Price = 11.14
# Rating = 4
# Quantity = 70
# Name = Pesto with basil
# Type = vegetable
# Description = Italian traditional pesto with basil, chesse and oil
# Height = 450
# Weight = 299
# Price = 18.19
# Rating = 2
# Quantity = 77
# Name = Hazelnut in black ceramic bowl
# Type = vegetable
# Description = Hazelnut in black ceramic bowl on old wooden background. forest wealth. rustic style. selective focus
# Height = 450
# Weight = 301
# Price = 27.35
# Rating = 0
# Quantity = 73
# Name = Fresh stawberry
# Type = fruit
# Description = Sweet fresh stawberry on the wooden table
# Height = 600
# Weight = 399
# Price = 28.59
# Rating = 4
# Quantity = 128
# Name = Lemon and salt
# Type = fruit
# Description = Rosemary, lemon and salt on the table
# Height = 450
# Weight = 299
# Price = 15.79
# Rating = 5
# Quantity = 61
# Name = Homemade bread
# Type = bakery
# Description = Homemade bread
# Height = 450
# Weight = 301
# Price = 17.48
# Rating = 3
# Quantity = 91
# Name = Legums
# Type = vegetable
# Description = Cooked legums on the wooden table
# Height = 600
# Weight = 399
# Price = 14.77
# Rating = 0
# Quantity = 104
# Name = Fresh tomato
# Type = vegetable
# Description = Fresh tomato juice with basil
# Height = 600
# Weight = 903
# Price = 16.3
# Rating = 2
# Quantity = 148
# Name = Healthy breakfast
# Type = fruit
# Description = Healthy breakfast set. rice cereal or porridge with berries and honey over rustic wood background
# Height = 450
# Weight = 350
# Price = 13.02
# Rating = 2
# Quantity = 66
# Name = Green beans
# Type = vegetable
# Description = Raw organic green beans ready to eat
# Height = 450
# Weight = 300
# Price = 28.79
# Rating = 1
# Quantity = 135
# Name = Baked stuffed portabello mushrooms
# Type = bakery
# Description = Homemade baked stuffed portabello mushrooms with spinach and cheese
# Height = 600
# Weight = 400
# Price = 20.31
# Rating = 1
# Quantity = 71
# Name = Strawberry jelly
# Type = fruit
# Description = Homemade organic strawberry jelly in a jar
# Height = 400
# Weight = 600
# Price = 14.18
# Rating = 1
# Quantity = 71
# Name = Pears juice
# Type = fruit
# Description = Fresh pears juice on the wooden table
# Height = 600
# Weight = 398
# Price = 19.49
# Rating = 4
# Quantity = 127
# Name = Fresh pears
# Type = fruit
# Description = Sweet fresh pears on the wooden table
# Height = 600
# Weight = 398
# Price = 15.12
# Rating = 5
# Quantity = 92
# Name = Caprese salad
# Type = vegetable
# Description = Homemade healthy caprese salad with tomato mozzarella and basil
# Height = 400
# Weight = 600
# Price = 16.76
# Rating = 5
# Quantity = 62
# Name = Oranges
# Type = fruit
# Description = Orange popsicle ice cream bars made from fresh oranges.  a refreshing summer treat.
# Height = 450
# Weight = 274
# Price = 21.48
# Rating = 4
# Quantity = 75
# Name = Vegan food
# Type = vegetable
# Description = Concept of vegan food
# Height = 450
# Weight = 299
# Price = 29.66
# Rating = 4
# Quantity = 74
# Name = Breakfast with muesli
# Type = dairy
# Description = Concept of healthy breakfast with muesli
# Height = 450
# Weight = 299
# Price = 22.7
# Rating = 2
# Quantity = 134
# Name = Honey
# Type = bakery
# Description = Honey and honeycell on the table
# Height = 450
# Weight = 299
# Price = 17.01
# Rating = 2
# Quantity = 143
# Name = Breakfast with cottage
# Type = fruit
# Description = Healthy breakfast with cottage cheese and strawberry
# Height = 600
# Weight = 398
# Price = 14.05
# Rating = 1
# Quantity = 131
# Name = Strawberry smoothie
# Type = fruit
# Description = Glass of red strawberry smoothie with chia seeds, served with retro cocktail tube, fresh mint and strawberries over dark background
# Height = 600
# Weight = 400
# Price = 28.86
# Rating = 2
# Quantity = 136
# Name = Strawberry and mint
# Type = fruit
# Description = Homemade muesli with strawberry and mint
# Height = 450
# Weight = 299
# Price = 26.21
# Rating = 4
# Quantity = 63
# Name = Ricotta
# Type = dairy
# Description = Ricotta with berry and mint
# Height = 600
# Weight = 398
# Price = 27.81
# Rating = 5
# Quantity = 66
# Name = Cuban sandwiche
# Type = bakery
# Description = Homemade traditional cuban sandwiches with ham pork and cheese
# Height = 450
# Weight = 300
# Price = 18.5
# Rating = 4
# Quantity = 92
# Name = Granola
# Type = dairy
# Description = Glass jar with homemade granola and yogurt with nuts, raspberries and blackberries on wooden cutting board over white textile in day light
# Height = 450
# Weight = 300
# Price = 29.97
# Rating = 3
# Quantity = 75
# Name = Smoothie with chia seeds
# Type = fruit
# Description = Glass of red strawberry smoothie with chia seeds, served with retro cocktail tube, fresh mint and strawberries over wooden table
# Height = 600
# Weight = 900
# Price = 25.26
# Rating = 5
# Quantity = 84
# Name = Yogurt
# Type = dairy
# Description = Homemade yogurt with raspberry and mint
# Height = 450
# Weight = 299
# Price = 27.61
# Rating = 4
# Quantity = 73
# Name = Sandwich with salad
# Type = vegetable
# Description = Vegan sandwich with salad, tomato and radish
# Height = 600
# Weight = 398
# Price = 22.48
# Rating = 5
# Quantity = 99
# Name = Cherry
# Type = fruit
# Description = Cherry with sugar on old table
# Height = 600
# Weight = 400
# Price = 14.35
# Rating = 5
# Quantity = 138
# Name = Raw asparagus
# Type = vegetable
# Description = Raw fresh asparagus salad with cheese and dressing
# Height = 600
# Weight = 400
# Price = 22.97
# Rating = 4
# Quantity = 98
# Name = Corn
# Type = vegetable
# Description = Grilled corn on the cob with salt and butter
# Height = 450
# Weight = 300
# Price = 13.55
# Rating = 2
# Quantity = 93
# Name = Vegan
# Type = vegan
# Description = Concept of healthy vegan eating
# Height = 600
# Weight = 398
# Price = 28.96
# Rating = 5
# Quantity = 126
# Name = Fresh blueberries
# Type = fruit
# Description = Healthy breakfast. berry crumble with fresh blueberries, raspberries, strawberries, almond, walnuts, pecans, yogurt, and mint in ceramic plates over white wooden surface, top view
# Height = 450
# Weight = 321
# Price = 21.01
# Rating = 4
# Quantity = 100
# Name = Smashed avocado
# Type = fruit
# Description = Vegan sandwiches with smashed avocado, tomatoes and radish. top view
# Height = 450
# Weight = 450
# Price = 25.88
# Rating = 0
# Quantity = 62
# Name = Italian ciabatta
# Type = bakery
# Description = Italian ciabatta bread cut in slices on wooden chopping board with herbs, garlic and olives over dark grunge backdrop, top view
# Height = 450
# Weight = 565
# Price = 15.18
# Rating = 1
# Quantity = 80
# Name = Rustic breakfast
# Type = dairy
# Description = Rustic healthy breakfast set. cooked buckwheat groats with milk and honey on dark grunge backdrop. top view, copy space
# Height = 450
# Weight = 307
# Price = 21.32
# Rating = 0
# Quantity = 61
# Name = Sliced lemons
# Type = fruit
# Description = Heap of whole and sliced lemons and limes with mint in vintage metal grid box over old wooden table with turquoise wooden background. dark rustic style.
# Height = 600
# Weight = 900
# Price = 27.14
# Rating = 2
# Quantity = 109
# Name = Plums
# Type = fruit
# Description = Yellow and red sweet plums
# Height = 450
# Weight = 299
# Price = 19.18
# Rating = 1
# Quantity = 83
# Name = French fries
# Type = bakery
# Description = Homemade oven baked french fries with ketchup
# Height = 600
# Weight = 400
# Price = 18.32
# Rating = 3
# Quantity = 51
# Name = Strawberries
# Type = fruit
# Description = Healthy breakfast set. rice cereal or porridge with fresh strawberry, apricots, almond and honey over white rustic wood backdrop, top view.
# Height = 450
# Weight = 352
# Price = 15.13
# Rating = 3
# Quantity = 58
# Name = Ground beef meat burger
# Type = meat
# Description = Raw ground beef meat burger steak cutlets with seasoning on vintage wooden boards, black background
# Height = 450
# Weight = 675
# Price = 11.73
# Rating = 5
# Quantity = 96
# Name = Tomatoes
# Type = fruit
# Description = Organic tomatoes made with love
# Height = 450
# Weight = 675
# Price = 26.03
# Rating = 4
# Quantity = 96
# Name = Basil
# Type = vegetable
# Description = Concept of vegan food with basil
# Height = 450
# Weight = 678
# Price = 15.19
# Rating = 4
# Quantity = 140
# Name = Fruits bouquet
# Type = fruit
# Description = Abstract citrus fruits bouquet on blue background
# Height = 600
# Weight = 401
# Price = 18.18
# Rating = 1
# Quantity = 65
# Name = Peaches on branch
# Type = fruit
# Description = Peaches on branch with leaves and glasses with peach juice and limonade with ice cubes in aluminum tray over old metal table. dark rustic style. top view.
# Height = 600
# Weight = 400
# Price = 25.62
# Rating = 3
# Quantity = 117
# Name = Fivestar
# Type = Chocolate
# Description = Caramel filled bar coated with melted chocolate
# Height = 10
# Weight = 4
# Price = 20.0
# Rating = 4
# Quantity = 90
# {'11201': {'title': 'Brown eggs', 'type': 'dairy', 'description': 'Raw organic brown eggs in a basket', 'height': 600, 'width': 400, 'price': 28.1, 'rating': 4, 'quantity': 107}, '11202': {'title': 'Sweet fresh stawberry', 'type': 'fruit', 'description': 'Sweet fresh stawberry on the wooden table', 'height': 450, 'width': 299, 'price': 29.45, 'rating': 4, 'quantity': 54}, '11203': {'title': 'Asparagus', 'type': 'vegetable', 'description': 'Asparagus with ham on the wooden table', 'height': 450, 'width': 299, 'price': 18.95, 'rating': 3, 'quantity': 101}, '11204': {'title': 'Green smoothie', 'type': 'dairy', 'description': "Glass of green smoothie with quail egg's yolk, served with cocktail tube, green apple and baby spinach leaves over tin surface.", 'height': 600, 'width': 399, 'price': 17.68, 'rating': 4, 'quantity': 95}, '11205': {'title': 'Raw legums', 'type': 'vegetable', 'description': 'Raw legums on the wooden table', 'height': 450, 'width': 299, 'price': 17.11, 'rating': 2, 'quantity': 145}, '11206': {'title': 'Baking cake', 'type': 'dairy', 'description': 'Baking cake in rural kitchen - dough  recipe ingredients (eggs, flour, sugar) on vintage wooden table from above.', 'height': 450, 'width': 675, 'price': 11.14, 'rating': 4, 'quantity': 70}, '11207': {'title': 'Pesto with basil', 'type': 'vegetable', 'description': 'Italian traditional pesto with basil, chesse and oil', 'height': 450, 'width': 299, 'price': 18.19, 'rating': 2, 'quantity': 77}, '11208': {'title': 'Hazelnut in black ceramic bowl', 'type': 'vegetable', 'description': 'Hazelnut in black ceramic bowl on old wooden background. forest wealth. rustic style. selective focus', 'height': 450, 'width': 301, 'price': 27.35, 'rating': 0, 'quantity': 73}, '11209': {'title': 'Fresh stawberry', 'type': 'fruit', 'description': 'Sweet fresh stawberry on the wooden table', 'height': 600, 'width': 399, 'price': 28.59, 'rating': 4, 'quantity': 128}, '11210': {'title': 'Lemon and salt', 'type': 'fruit', 'description': 'Rosemary, lemon and salt on the table', 'height': 450, 'width': 299, 'price': 15.79, 'rating': 5, 'quantity': 61}, '11211': {'title': 'Homemade bread', 'type': 'bakery', 'description': 'Homemade bread', 'height': 450, 'width': 301, 'price': 17.48, 'rating': 3, 'quantity': 91}, '11212': {'title': 'Legums', 'type': 'vegetable', 'description': 'Cooked legums on the wooden table', 'height': 600, 'width': 399, 'price': 14.77, 'rating': 0, 'quantity': 104}, '11213': {'title': 'Fresh tomato', 'type': 'vegetable', 'description': 'Fresh tomato juice with basil', 'height': 600, 'width': 903, 'price': 16.3, 'rating': 2, 'quantity': 148}, '11214': {'title': 'Healthy breakfast', 'type': 'fruit', 'description': 'Healthy breakfast set. rice cereal or porridge with berries and honey over rustic wood background', 'height': 450, 'width': 350, 'price': 13.02, 'rating': 2, 'quantity': 66}, '11215': {'title': 'Green beans', 'type': 'vegetable', 'description': 'Raw organic green beans ready to eat', 'height': 450, 'width': 300, 'price': 28.79, 'rating': 1, 'quantity': 135}, '11216': {'title': 'Baked stuffed portabello mushrooms', 'type': 'bakery', 'description': 'Homemade baked stuffed portabello mushrooms with spinach and cheese', 'height': 600, 'width': 400, 'price': 20.31, 'rating': 1, 'quantity': 71}, '11217': {'title': 'Strawberry jelly', 'type': 'fruit', 'description': 'Homemade organic strawberry jelly in a jar', 'height': 400, 'width': 600, 'price': 14.18, 'rating': 1, 'quantity': 71}, '11218': {'title': 'Pears juice', 'type': 'fruit', 'description': 'Fresh pears juice on the wooden table', 'height': 600, 'width': 398, 'price': 19.49, 'rating': 4, 'quantity': 127}, '11219': {'title': 'Fresh pears', 'type': 'fruit', 'description': 'Sweet fresh pears on the wooden table', 'height': 600, 'width': 398, 'price': 15.12, 'rating': 5, 'quantity': 92}, '11220': {'title': 'Caprese salad', 'type': 'vegetable', 'description': 'Homemade healthy caprese salad with tomato mozzarella an ...

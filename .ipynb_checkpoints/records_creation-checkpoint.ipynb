# %% [markdown]
# # This file is created for the creation of record.json file.
# #### This is the record i used for inventory management

# %%
records = {11201 : {
  "title": "Brown eggs",
  "type": "dairy",
  "description": "Raw organic brown eggs in a basket",
  "filename": "0.jpg",
  "height": 600,
  "width": 400,
  "price": 28.1,
  "rating": 4
}, 11202 : {
  "title": "Sweet fresh stawberry",
  "type": "fruit",
  "description": "Sweet fresh stawberry on the wooden table",
  "filename": "1.jpg",
  "height": 450,
  "width": 299,
  "price": 29.45,
  "rating": 4
}, 11203 : {
  "title": "Asparagus",
  "type": "vegetable",
  "description": "Asparagus with ham on the wooden table",
  "filename": "2.jpg",
  "height": 450,
  "width": 299,
  "price": 18.95,
  "rating": 3
}, 11204 : {
  "title": "Green smoothie",
  "type": "dairy",
  "description": "Glass of green smoothie with quail egg's yolk, served with cocktail tube, green apple and baby spinach leaves over tin surface.",
  "filename": "3.jpg",
  "height": 600,
  "width": 399,
  "price": 17.68,
  "rating": 4
},11205 :  {
  "title": "Raw legums",
  "type": "vegetable",
  "description": "Raw legums on the wooden table",
  "filename": "4.jpg",
  "height": 450,
  "width": 299,
  "price": 17.11,
  "rating": 2
}, 11206 : {
  "title": "Baking cake",
  "type": "dairy",
  "description": "Baking cake in rural kitchen - dough  recipe ingredients (eggs, flour, sugar) on vintage wooden table from above.",
  "filename": "5.jpg",
  "height": 450,
  "width": 675,
  "price": 11.14,
  "rating": 4
}, 11207 : {
  "title": "Pesto with basil",
  "type": "vegetable",
  "description": "Italian traditional pesto with basil, chesse and oil",
  "filename": "6.jpg",
  "height": 450,
  "width": 299,
  "price": 18.19,
  "rating": 2
},11208 :  {
  "title": "Hazelnut in black ceramic bowl",
  "type": "vegetable",
  "description": "Hazelnut in black ceramic bowl on old wooden background. forest wealth. rustic style. selective focus",
  "filename": "7.jpg",
  "height": 450,
  "width": 301,
  "price": 27.35,
  "rating": 0
}, 11209 : {
  "title": "Fresh stawberry",
  "type": "fruit",
  "description": "Sweet fresh stawberry on the wooden table",
  "filename": "8.jpg",
  "height": 600,
  "width": 399,
  "price": 28.59,
  "rating": 4
}, 11210 : {
  "title": "Lemon and salt",
  "type": "fruit",
  "description": "Rosemary, lemon and salt on the table",
  "filename": "9.jpg",
  "height": 450,
  "width": 299,
  "price": 15.79,
  "rating": 5
}, 11211 : {
  "title": "Homemade bread",
  "type": "bakery",
  "description": "Homemade bread",
  "filename": "10.jpg",
  "height": 450,
  "width": 301,
  "price": 17.48,
  "rating": 3
}, 11212 : {
  "title": "Legums",
  "type": "vegetable",
  "description": "Cooked legums on the wooden table",
  "filename": "11.jpg",
  "height": 600,
  "width": 399,
  "price": 14.77,
  "rating": 0
}, 11213 : {
  "title": "Fresh tomato",
  "type": "vegetable",
  "description": "Fresh tomato juice with basil",
  "filename": "12.jpg",
  "height": 600,
  "width": 903,
  "price": 16.3,
  "rating": 2
}, 11214 : {
  "title": "Healthy breakfast",
  "type": "fruit",
  "description": "Healthy breakfast set. rice cereal or porridge with berries and honey over rustic wood background",
  "filename": "13.jpg",
  "height": 450,
  "width": 350,
  "price": 13.02,
  "rating": 2
}, 11215 : {
  "title": "Green beans",
  "type": "vegetable",
  "description": "Raw organic green beans ready to eat",
  "filename": "14.jpg",
  "height": 450,
  "width": 300,
  "price": 28.79,
  "rating": 1
}, 11216 : {
  "title": "Baked stuffed portabello mushrooms",
  "type": "bakery",
  "description": "Homemade baked stuffed portabello mushrooms with spinach and cheese",
  "filename": "15.jpg",
  "height": 600,
  "width": 400,
  "price": 20.31,
  "rating": 1
}, 11217 : {
  "title": "Strawberry jelly",
  "type": "fruit",
  "description": "Homemade organic strawberry jelly in a jar",
  "filename": "16.jpg",
  "height": 400,
  "width": 600,
  "price": 14.18,
  "rating": 1
}, 11218 : {
  "title": "Pears juice",
  "type": "fruit",
  "description": "Fresh pears juice on the wooden table",
  "filename": "17.jpg",
  "height": 600,
  "width": 398,
  "price": 19.49,
  "rating": 4
}, 11219 : {
  "title": "Fresh pears",
  "type": "fruit",
  "description": "Sweet fresh pears on the wooden table",
  "filename": "18.jpg",
  "height": 600,
  "width": 398,
  "price": 15.12,
  "rating": 5
},11220 :  {
  "title": "Caprese salad",
  "type": "vegetable",
  "description": "Homemade healthy caprese salad with tomato mozzarella and basil",
  "filename": "19.jpg",
  "height": 400,
  "width": 600,
  "price": 16.76,
  "rating": 5
},11221 : {
  "title": "Oranges",
  "type": "fruit",
  "description": "Orange popsicle ice cream bars made from fresh oranges.  a refreshing summer treat.",
  "filename": "20.jpg",
  "height": 450,
  "width": 274,
  "price": 21.48,
  "rating": 4
},11222 :  {
  "title": "Vegan food",
  "type": "vegetable",
  "description": "Concept of vegan food",
  "filename": "21.jpg",
  "height": 450,
  "width": 299,
  "price": 29.66,
  "rating": 4
}, 11223 : {
  "title": "Breakfast with muesli",
  "type": "dairy",
  "description": "Concept of healthy breakfast with muesli",
  "filename": "22.jpg",
  "height": 450,
  "width": 299,
  "price": 22.7,
  "rating": 2
},11224 : {
  "title": "Honey",
  "type": "bakery",
  "description": "Honey and honeycell on the table",
  "filename": "23.jpg",
  "height": 450,
  "width": 299,
  "price": 17.01,
  "rating": 2
},11225 :  {
  "title": "Breakfast with cottage",
  "type": "fruit",
  "description": "Healthy breakfast with cottage cheese and strawberry",
  "filename": "24.jpg",
  "height": 600,
  "width": 398,
  "price": 14.05,
  "rating": 1
},11226 :  {
  "title": "Strawberry smoothie",
  "type": "fruit",
  "description": "Glass of red strawberry smoothie with chia seeds, served with retro cocktail tube, fresh mint and strawberries over dark background",
  "filename": "25.jpg",
  "height": 600,
  "width": 400,
  "price": 28.86,
  "rating": 2
}, 11227 : {
  "title": "Strawberry and mint",
  "type": "fruit",
  "description": "Homemade muesli with strawberry and mint",
  "filename": "26.jpg",
  "height": 450,
  "width": 299,
  "price": 26.21,
  "rating": 4
},11228 :  {
  "title": "Ricotta",
  "type": "dairy",
  "description": "Ricotta with berry and mint",
  "filename": "27.jpg",
  "height": 600,
  "width": 398,
  "price": 27.81,
  "rating": 5
}, 11229 : {
  "title": "Cuban sandwiche",
  "type": "bakery",
  "description": "Homemade traditional cuban sandwiches with ham pork and cheese",
  "filename": "28.jpg",
  "height": 450,
  "width": 300,
  "price": 18.5,
  "rating": 4
},11230 :  {
  "title": "Granola",
  "type": "dairy",
  "description": "Glass jar with homemade granola and yogurt with nuts, raspberries and blackberries on wooden cutting board over white textile in day light",
  "filename": "29.jpg",
  "height": 450,
  "width": 300,
  "price": 29.97,
  "rating": 3
},11231 :  {
  "title": "Smoothie with chia seeds",
  "type": "fruit",
  "description": "Glass of red strawberry smoothie with chia seeds, served with retro cocktail tube, fresh mint and strawberries over wooden table",
  "filename": "30.jpg",
  "height": 600,
  "width": 900,
  "price": 25.26,
  "rating": 5
},11232 :  {
  "title": "Yogurt",
  "type": "dairy",
  "description": "Homemade yogurt with raspberry and mint",
  "filename": "31.jpg",
  "height": 450,
  "width": 299,
  "price": 27.61,
  "rating": 4
},11233 :  {
  "title": "Sandwich with salad",
  "type": "vegetable",
  "description": "Vegan sandwich with salad, tomato and radish",
  "filename": "32.jpg",
  "height": 600,
  "width": 398,
  "price": 22.48,
  "rating": 5
}, 11234 : {
  "title": "Cherry",
  "type": "fruit",
  "description": "Cherry with sugar on old table",
  "filename": "33.jpg",
  "height": 600,
  "width": 400,
  "price": 14.35,
  "rating": 5
},11235 :  {
  "title": "Raw asparagus",
  "type": "vegetable",
  "description": "Raw fresh asparagus salad with cheese and dressing",
  "filename": "34.jpg",
  "height": 600,
  "width": 400,
  "price": 22.97,
  "rating": 4
}, 11236 : {
  "title": "Corn",
  "type": "vegetable",
  "description": "Grilled corn on the cob with salt and butter",
  "filename": "35.jpg",
  "height": 450,
  "width": 300,
  "price": 13.55,
  "rating": 2
},11237:  {
  "title": "Vegan",
  "type": "vegan",
  "description": "Concept of healthy vegan eating",
  "filename": "36.jpg",
  "height": 600,
  "width": 398,
  "price": 28.96,
  "rating": 5
},11238 :  {
  "title": "Fresh blueberries",
  "type": "fruit",
  "description": "Healthy breakfast. berry crumble with fresh blueberries, raspberries, strawberries, almond, walnuts, pecans, yogurt, and mint in ceramic plates over white wooden surface, top view",
  "filename": "37.jpg",
  "height": 450,
  "width": 321,
  "price": 21.01,
  "rating": 4
},11239 :  {
  "title": "Smashed avocado",
  "type": "fruit",
  "description": "Vegan sandwiches with smashed avocado, tomatoes and radish. top view",
  "filename": "38.jpg",
  "height": 450,
  "width": 450,
  "price": 25.88,
  "rating": 0
}, 11240 : {
  "title": "Italian ciabatta",
  "type": "bakery",
  "description": "Italian ciabatta bread cut in slices on wooden chopping board with herbs, garlic and olives over dark grunge backdrop, top view",
  "filename": "39.jpg",
  "height": 450,
  "width": 565,
  "price": 15.18,
  "rating": 1
}, 11241 : {
  "title": "Rustic breakfast",
  "type": "dairy",
  "description": "Rustic healthy breakfast set. cooked buckwheat groats with milk and honey on dark grunge backdrop. top view, copy space",
  "filename": "40.jpg",
  "height": 450,
  "width": 307,
  "price": 21.32,
  "rating": 0
},11242 :  {
  "title": "Sliced lemons",
  "type": "fruit",
  "description": "Heap of whole and sliced lemons and limes with mint in vintage metal grid box over old wooden table with turquoise wooden background. dark rustic style.",
  "filename": "41.jpg",
  "height": 600,
  "width": 900,
  "price": 27.14,
  "rating": 2
},11243 :  {
  "title": "Plums",
  "type": "fruit",
  "description": "Yellow and red sweet plums",
  "filename": "42.jpg",
  "height": 450,
  "width": 299,
  "price": 19.18,
  "rating": 1
}, 11244 : {
  "title": "French fries",
  "type": "bakery",
  "description": "Homemade oven baked french fries with ketchup",
  "filename": "43.jpg",
  "height": 600,
  "width": 400,
  "price": 18.32,
  "rating": 3
},11245 :  {
  "title": "Strawberries",
  "type": "fruit",
  "description": "Healthy breakfast set. rice cereal or porridge with fresh strawberry, apricots, almond and honey over white rustic wood backdrop, top view.",
  "filename": "44.jpg",
  "height": 450,
  "width": 352,
  "price": 15.13,
  "rating": 3
},11246 :  {
  "title": "Ground beef meat burger",
  "type": "meat",
  "description": "Raw ground beef meat burger steak cutlets with seasoning on vintage wooden boards, black background",
  "filename": "45.jpg",
  "height": 450,
  "width": 675,
  "price": 11.73,
  "rating": 5
},11247 :  {
  "title": "Tomatoes",
  "type": "fruit",
  "description": "Organic tomatoes made with love",
  "filename": "46.jpg",
  "height": 450,
  "width": 675,
  "price": 26.03,
  "rating": 4
},11248 : {
  "title": "Basil",
  "type": "vegetable",
  "description": "Concept of vegan food with basil",
  "filename": "47.jpg",
  "height": 450,
  "width": 678,
  "price": 15.19,
  "rating": 4
}, 11249 : {
  "title": "Fruits bouquet",
  "type": "fruit",
  "description": "Abstract citrus fruits bouquet on blue background",
  "filename": "48.jpg",
  "height": 600,
  "width": 401,
  "price": 18.18,
  "rating": 1
},11250 :  {
  "title": "Peaches on branch",
  "type": "fruit",
  "description": "Peaches on branch with leaves and glasses with peach juice and limonade with ice cubes in aluminum tray over old metal table. dark rustic style. top view.",
  "filename": "49.jpg",
  "height": 600,
  "width": 400,
  "price": 25.62,
  "rating": 3
}}
len(records)
# Out:
# 50

# %%
import random
for i in range(1,len(records)+1):
    if i < 10:
        key = int('1120' + str(i))
    else:
        key = int('112' + str(i))
    # For deleting un needed features
    #del records[key]["filename"]
    
    # To add new features
    records[key]['quantity'] = random.randint(50,150)
# Out:
# 11201 {'title': 'Brown eggs', 'type': 'dairy', 'description': 'Raw organic brown eggs in a basket', 'height': 600, 'width': 400, 'price': 28.1, 'rating': 4, 'quantity': 107}
# 11202 {'title': 'Sweet fresh stawberry', 'type': 'fruit', 'description': 'Sweet fresh stawberry on the wooden table', 'height': 450, 'width': 299, 'price': 29.45, 'rating': 4, 'quantity': 54}
# 11203 {'title': 'Asparagus', 'type': 'vegetable', 'description': 'Asparagus with ham on the wooden table', 'height': 450, 'width': 299, 'price': 18.95, 'rating': 3, 'quantity': 101}
# 11204 {'title': 'Green smoothie', 'type': 'dairy', 'description': "Glass of green smoothie with quail egg's yolk, served with cocktail tube, green apple and baby spinach leaves over tin surface.", 'height': 600, 'width': 399, 'price': 17.68, 'rating': 4, 'quantity': 95}
# 11205 {'title': 'Raw legums', 'type': 'vegetable', 'description': 'Raw legums on the wooden table', 'height': 450, 'width': 299, 'price': 17.11, 'rating': 2, 'quantity': 145}
# 11206 {'title': 'Baking cake', 'type': 'dairy', 'description': 'Baking cake in rural kitchen - dough  recipe ingredients (eggs, flour, sugar) on vintage wooden table from above.', 'height': 450, 'width': 675, 'price': 11.14, 'rating': 4, 'quantity': 70}
# 11207 {'title': 'Pesto with basil', 'type': 'vegetable', 'description': 'Italian traditional pesto with basil, chesse and oil', 'height': 450, 'width': 299, 'price': 18.19, 'rating': 2, 'quantity': 80}
# 11208 {'title': 'Hazelnut in black ceramic bowl', 'type': 'vegetable', 'description': 'Hazelnut in black ceramic bowl on old wooden background. forest wealth. rustic style. selective focus', 'height': 450, 'width': 301, 'price': 27.35, 'rating': 0, 'quantity': 73}
# 11209 {'title': 'Fresh stawberry', 'type': 'fruit', 'description': 'Sweet fresh stawberry on the wooden table', 'height': 600, 'width': 399, 'price': 28.59, 'rating': 4, 'quantity': 128}
# 11210 {'title': 'Lemon and salt', 'type': 'fruit', 'description': 'Rosemary, lemon and salt on the table', 'height': 450, 'width': 299, 'price': 15.79, 'rating': 5, 'quantity': 61}
# 11211 {'title': 'Homemade bread', 'type': 'bakery', 'description': 'Homemade bread', 'height': 450, 'width': 301, 'price': 17.48, 'rating': 3, 'quantity': 91}
# 11212 {'title': 'Legums', 'type': 'vegetable', 'description': 'Cooked legums on the wooden table', 'height': 600, 'width': 399, 'price': 14.77, 'rating': 0, 'quantity': 104}
# 11213 {'title': 'Fresh tomato', 'type': 'vegetable', 'description': 'Fresh tomato juice with basil', 'height': 600, 'width': 903, 'price': 16.3, 'rating': 2, 'quantity': 149}
# 11214 {'title': 'Healthy breakfast', 'type': 'fruit', 'description': 'Healthy breakfast set. rice cereal or porridge with berries and honey over rustic wood background', 'height': 450, 'width': 350, 'price': 13.02, 'rating': 2, 'quantity': 66}
# 11215 {'title': 'Green beans', 'type': 'vegetable', 'description': 'Raw organic green beans ready to eat', 'height': 450, 'width': 300, 'price': 28.79, 'rating': 1, 'quantity': 135}
# 11216 {'title': 'Baked stuffed portabello mushrooms', 'type': 'bakery', 'description': 'Homemade baked stuffed portabello mushrooms with spinach and cheese', 'height': 600, 'width': 400, 'price': 20.31, 'rating': 1, 'quantity': 71}
# 11217 {'title': 'Strawberry jelly', 'type': 'fruit', 'description': 'Homemade organic strawberry jelly in a jar', 'height': 400, 'width': 600, 'price': 14.18, 'rating': 1, 'quantity': 71}
# 11218 {'title': 'Pears juice', 'type': 'fruit', 'description': 'Fresh pears juice on the wooden table', 'height': 600, 'width': 398, 'price': 19.49, 'rating': 4, 'quantity': 127}
# 11219 {'title': 'Fresh pears', 'type': 'fruit', 'description': 'Sweet fresh pears on the wooden table', 'height': 600, 'width': 398, 'price': 15.12, 'rating': 5, 'quantity': 92}
# 11220 {'title': 'Caprese salad', 'type': 'vegetable', 'description': 'Homemade healthy caprese salad with tomato mozzarella and basil', 'height': 400, 'width': 600, 'price': 16.76, 'rating': 5, 'quantity': 62}
# 11221 {'title': 'Oranges', 'type': 'fruit', 'description': 'Orange popsicle ice cream bars made from fresh oranges.  a refreshing summer treat.', 'height': 450, 'width': 274, 'price': 21.48, 'rating': 4, 'quantity': 75}
# 11222 {'title': 'Vegan food', 'type': 'vegetable', 'description': 'Concept of vegan food', 'height': 450, 'width': 299, 'price': 29.66, 'rating': 4, 'quantity': 74}
# 11223 {'title': 'Breakfast with muesli', 'type': 'dairy', 'description': 'Concept of healthy breakfast with muesli', 'height': 450, 'width': 299, 'price': 22.7, 'rating': 2, 'quantity': 135}
# 11224 {'title': 'Honey', 'type': 'bakery', 'description': 'Honey and honeycell on the table', 'height': 450, 'width': 299, 'price': 17.01, 'rating': 2, 'quantity': 143}
# 11225 {'title': 'Breakfast with cottage', 'type': 'fruit', 'description': 'Healthy breakfast with cottage cheese and strawberry', 'height': 600, 'width': 398, 'price': 14.05, 'rating': 1, 'quantity': 131}
# 11226 {'title': 'Strawberry smoothie', 'type': 'fruit', 'description': 'Glass of red strawberry smoothie with chia seeds, served with retro cocktail tube, fresh mint and strawberries over dark background', 'height': 600, 'width': 400, 'price': 28.86, 'rating': 2, 'quantity': 136}
# 11227 {'title': 'Strawberry and mint', 'type': 'fruit', 'description': 'Homemade muesli with strawberry and mint', 'height': 450, 'width': 299, 'price': 26.21, 'rating': 4, 'quantity': 63}
# 11228 {'title': 'Ricotta', 'type': 'dairy', 'description': 'Ricotta with berry and mint', 'height': 600, 'width': 398, 'price': 27.81, 'rating': 5, 'quantity': 66}
# 11229 {'title': 'Cuban sandwiche', 'type': 'bakery', 'description': 'Homemade traditional cuban sandwiches with ham pork and cheese', 'height': 450, 'width': 300, 'price': 18.5, 'rating': 4, 'quantity': 92}
# 11230 {'title': 'Granola', 'type': 'dairy', 'description': 'Glass jar with homemade granola and yogurt with nuts, raspberries and blackberries on wooden cutting board over white textile in day light', 'height': 450, 'width': 300, 'price': 29.97, 'rating': 3, 'quantity': 78}
# 11231 {'title': 'Smoothie with chia seeds', 'type': 'fruit', 'description': 'Glass of red strawberry smoothie with chia seeds, served with retro cocktail tube, fresh mint and strawberries over wooden table', 'height': 600, 'width': 900, 'price': 25.26, 'rating': 5, 'quantity': 84}
# 11232 {'title': 'Yogurt', 'type': 'dairy', 'description': 'Homemade yogurt with raspberry and mint', 'height': 450, 'width': 299, 'price': 27.61, 'rating': 4, 'quantity': 73}
# 11233 {'title': 'Sandwich with salad', 'type': 'vegetable', 'description': 'Vegan sandwich with salad, tomato and radish', 'height': 600, 'width': 398, 'price': 22.48, 'rating': 5, 'quantity': 99}
# 11234 {'title': 'Cherry', 'type': 'fruit', 'description': 'Cherry with sugar on old table', 'height': 600, 'width': 400, 'price': 14.35, 'rating': 5, 'quantity': 138}
# 11235 {'title': 'Raw asparagus', 'type': 'vegetable', 'description': 'Raw fresh asparagus salad with cheese and dressing', 'height': 600, 'width': 400, 'price': 22.97, 'rating': 4, 'quantity': 98}
# 11236 {'title': 'Corn', 'type': 'vegetable', 'description': 'Grilled corn on the cob with salt and butter', 'height': 450, 'width': 300, 'price': 13.55, 'rating': 2, 'quantity': 93}
# 11237 {'title': 'Vegan', 'type': 'vegan', 'description': 'Concept of healthy vegan eating', 'height': 600, 'width': 398, 'price': 28.96, 'rating': 5, 'quantity': 126}
# 11238 {'title': 'Fresh blueberries', 'type': 'fruit', 'description': 'Healthy breakfast. berry crumble with fresh blueberries, raspberries, strawberries, almond, walnuts, pecans, yogurt, and mint in ceramic plates over white wooden surface, top view', 'height': 450, 'width': 321, 'price': 21.01, 'rating': 4, 'quantity': 100}
# 11239 {'title': 'Smashed avocado', 'type': 'fruit', 'description': 'Vegan sandwiches with smashed avocado, tomatoes and radish. top view', 'height': 450, 'width': 450, 'price': 25.88, 'rating': 0, 'quantity': 63}
# 11240 {'title': 'Italian ciabatta', 'type': 'bakery', 'description': 'Italian ciabatta bread cut in slices on wooden chopping board with herbs, garlic and olives over dark grunge backdrop, top view', 'height': 450, 'width': 565, 'price': 15.18, 'rating': 1, 'quantity': 83}
# 11241 {'title': 'Rustic breakfast', 'type': 'dairy', 'description': 'Rustic healthy breakfast set. cooked buckwheat groats with milk and honey on dark grunge backdrop. top view, copy space', 'height': 450, 'width': 307, 'price': 21.32, 'rating': 0, 'quantity': 61}
# 11242 {'title': 'Sliced lemons', 'type': 'fruit', 'description': 'Heap of whole and sliced lemons and limes with mint in vintage metal grid box over old wooden table with turquoise wooden background. dark rustic style.', 'height': 600, 'width': 900, 'price': 27.14, 'rating': 2, 'quantity': 109}
# 11243 {'title': 'Plums', 'type': 'fruit', 'description': 'Yellow and red sweet plums', 'height': 450, 'width': 299, 'price': 19.18, 'rating': 1, 'quantity': 83}
# 11244 {'title': 'French fries', 'type': 'bakery', 'description': 'Homemade oven baked french fries with ketchup', 'height': 600, 'width': 400, 'price': 18.32, 'rating': 3, 'quantity': 51}
# 11245 {'title': 'Strawberries', 'type': 'fruit', 'description': 'Healthy breakfast set. rice cereal or porridge with fresh strawberry, apricots, almond and honey over white rustic wood backdrop, top view.', 'height': 450, 'width': 352, 'price': 15.13, 'rating': 3, 'quantity': 58}
# 11246 {'title': 'Ground beef meat burger', 'type': 'meat', 'description': 'Raw ground beef meat burger steak cutlets with seasoning on vintage wooden boards, black background', 'height': 450, 'width': 675, 'price': 11.73, 'rating': 5, 'quantity': 96}
# 11247 {'title': 'Tomatoes', 'type': 'fruit', 'description': 'Organic tomatoes made with love', 'height': 450, 'width': 675, 'price': 26.03, 'rating': 4, 'quantity': 96}
# 11248 {'title': 'Basil', 'type': 'vegetable', 'description': 'Concept of vegan food with basil', 'height': 450, 'width': 678, 'price': 15.19, 'rating': 4, 'quantity': 140}
# 11249 {'title': 'Fruits bouquet', 'type': 'fruit', 'description': 'Abstract citrus fruits bouquet on blue background', 'height': 600, 'width': 401, 'price': 18.18, 'rating': 1, 'quantity': 65}
# 11250 {'title': 'Peaches on branch', 'type': 'fruit', 'description': 'Peaches on branch with leaves and glasses with peach juice and limonade with ice cubes in aluminum tray over old metal table. dark rustic style. top view.', 'height': 600, 'width': 400, 'price': 25.62, 'rating': 3, 'quantity': 117}

# %% [markdown]
# ### Saving record

# %%
import json
saved_record = json.dumps(records)

# %%
with open('records.json', 'w') as fd:
    fd.write(saved_record)
